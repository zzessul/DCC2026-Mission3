# %% [markdown]
# # DCC 2026 Mission 3 — KLUE-RoBERTa-large
# 런타임을 **GPU**로 변경한 뒤 위에서부터 실행하세요. `val.csv`는 마지막 예측 때만 사용합니다.

# %%
# !nvidia-smi
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Thu Sep 10 08:55:10 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !rm -rf /content/DCC2026-Mission3
# !git clone https://github.com/zzessul/DCC2026-Mission3.git /content/DCC2026-Mission3
# %cd /content/DCC2026-Mission3
# !ls
# !pip install -r /content/DCC2026-Mission3/requirements.txt
# Out:
# Cloning into '/content/DCC2026-Mission3'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 12 (delta 0), reused 9 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (12/12), 7.95 KiB | 7.95 MiB/s, done.
# /content/DCC2026-Mission3
# common.py		      predict.py  requirements.txt
# DCC2026_Mission3_Colab.ipynb  README.md   train.py
# ...

# %% [markdown]
# 아래 두 경로를 본인의 Google Drive 구조에 맞게 수정하세요.

# %%
TRAIN_CSV = '/content/drive/MyDrive/train.csv'
VAL_CSV = '/content/drive/MyDrive/val.csv'
OUTPUT_DIR = '/content/drive/MyDrive/DCC/checkpoints/klue_roberta_large'

# %% [markdown]
# ## 학습
# T4 메모리가 부족하면 `BATCH_SIZE=1`, `MAX_LENGTH=256`으로 변경하세요. 학습은 수 시간이 걸릴 수 있습니다.

# %%
BATCH_SIZE = 2
MAX_LENGTH = 384
# !python train.py --train_csv "{TRAIN_CSV}" --output_dir "{OUTPUT_DIR}" --model_name klue/roberta-large --batch_size {BATCH_SIZE} --max_length {MAX_LENGTH} --gradient_accumulation 8 --epochs 4
# Out:
# ...
# config.json: 100% 547/547 [00:00<00:00, 2.31MB/s]
# tokenizer_config.json: 100% 375/375 [00:00<00:00, 2.46MB/s]
# vocab.txt: 100% 248k/248k [00:00<00:00, 18.4MB/s]
# tokenizer.json: 100% 752k/752k [00:00<00:00, 83.7MB/s]
# special_tokens_map.json: 100% 173/173 [00:00<00:00, 1.10MB/s]
#
# model.safetensors: downloading bytes:  12% 156M/1.35G [00:01<00:06, 181MB/s, 12.6MB/s  ]
# model.safetensors: downloading bytes:  17% 227M/1.35G [00:02<00:08, 126MB/s, 19.4MB/s  ]
# model.safetensors: downloading bytes:  38% 518M/1.35G [00:03<00:04, 182MB/s, 42.0MB/s  ]
# model.safetensors: downloading bytes:  66% 884M/1.35G [00:05<00:01, 246MB/s, 64.3MB/s  ]
# model.safetensors: reconstructing file:  50% 671M/1.35G [00:07<00:07, 93.6MB/s, 33.7MB/s  ]
# model.safetensors: downloading bytes:  67% 902M/1.35G [00:18<00:01, 246MB/s, 67.4MB/s  ]
# model.safetensors: downloading bytes: 100% 902M/902M [00:23<00:00, 38.3MB/s, 67.4MB/s  ]
# ...

# %% [markdown]
# ## 공식 Validation 예측
# 모델 선택이 끝난 후 한 번만 실행하세요. 생성된 CSV를 팀 공통 `evaluate_colab.py`로 평가합니다.

# %%
PREDICTION_CSV = '/content/drive/MyDrive/DCC/val_predictions_klue_large.csv'
# !python predict.py --input_csv "{VAL_CSV}" --checkpoint_dir "{OUTPUT_DIR}" --output_csv "{PREDICTION_CSV}"
print(PREDICTION_CSV)
